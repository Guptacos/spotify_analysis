# %% [markdown]
# # Intro
#
# In this notebook, we will be reading from a pickle file, which will contain a list of songs through the years. Each element of this list will be a year of top songs, which is a list of dicts containing date, name, and artist. This list should contain the Billboard 100 songs for every week for the last 20 years, or as many years are available for that genre.
#
# Given this list, we will query the spotify API to generate a dataframe that contains the same information, augmented with song ID, song features, and artist genre. This dataframe will be saved as a pickle file at the end.

# %%
import spotipy
import spotipy.util as util

scope = ''
username = 'testname777123'
# Note: This should be filled in with an authentication token. Make sure to delete it before committing.
token = ''

sp = spotipy.Spotify(auth=token)

# %% [markdown]
# Let's create a cache of song mappings so as to limit our API requests to spotify.

# %%
# Format is dict{artist : {song : data, song : data ...} ...}
memo = dict()
unique_unfound = 0
total_unfound = 0

# %% [markdown]
# Now let's devise a way to get a song id, given a song and an artist:

# %%
from unidecode import unidecode
from fuzzywuzzy import fuzz

TITLE_DIFF = 70
ARTIST_DIFF = 70

def contains_artist(goal, artists):
    # Use unidecode to turn special characters to regular, i.e. ñ --> n
    goal = unidecode(goal).lower()
    
    for artist in artists:
        art = unidecode(artist['name']).lower()
        if fuzz.partial_ratio(art, goal) >= ARTIST_DIFF:
            return True

    return False

# If the song is not in the top 20 results, ignore it.
# TOOD: how frequently does this happen? If frequently, maybe follow the pages?
def get_song(track, artist):
    global unique_unfound
    track = unidecode(track).lower()
    artist = unidecode(artist).lower()
    
    extra_search_words = {'is', 'a', 'i', 'the'}
    
    split1 = track.split()
    first = split1[0]
    if split1[0] in extra_search_words and len(split1) > 1:
        first += ' ' + split1[1]
    
    split2 = artist.split()
    second = split2[0]
    if split2[0] in extra_search_words and len(split2) > 1:
        second += ' ' + split2[1]
        
    to_search = first + ' ' + second
    query_result = sp.search(q=to_search, type='track', limit=40)
    query_result = query_result['tracks']['items']
    
    # Clean the query results
    result = []
    for elem in query_result:
        cur_name = unidecode(elem['name']).lower()
        """
        arts = []
        for a in elem['artists']:
            arts += [a['name']]
        print(elem['name'], arts, fuzz.partial_ratio(track, cur_name), contains_artist(artist, elem['artists']))
        """
        if fuzz.partial_ratio(track, cur_name) < TITLE_DIFF:
            continue
        if not contains_artist(artist, elem['artists']):
            continue

        new_song = dict()
        new_song['name'] = cur_name
        new_song['id'] = elem['id']
        new_song['artist'] = artist
        new_song['popularity'] = elem['popularity']
        
        result += [new_song]
    
    # Return the most popular song
    result.sort(key=lambda d: d['popularity'])
    
    if len(result) == 0:
        print("Could not find '%s' by '%s' in top 20 results" % (track, artist))
        unique_unfound += 1
        return None
    
    return result[-1]

# %% [markdown]
# Create a wrapper to do it given a list of songs:

# %%
import pandas as pd
import copy

CHUNK_SIZE = 50

def divide_chunks(l, n):
    result = []
    for i in range(0, len(l), n):  
        if i >= len(l):
            result += [l[i:]]
        else:
            result += [l[i:i + n]]
    return result

def del_unneeded(d):
    del d['type']
    del d['id']
    del d['uri']
    del d['track_href']
    del d['analysis_url']
    #TODO: do we want time signature? Do we want to remove duration?
    del d['time_signature']
    
    return d

def combine_fn(a, b):
    a.update(b)
    return a

#TODO: should integrate 'retry_after' when response 429, to deal with rate limiting
# Expects song_list of type [dict{week, name, artist}....]
def convert_all_songs(song_list):
    global unique_unfound
    global total_unfound
    
    unique_unfound = 0
    total_unfound = 0
    
    result_data = []
    position = 0
    for song in song_list:
        artist = unidecode(song['artist']).lower()
        title = unidecode(song['name']).lower()
        if artist not in memo:
            memo[artist] = dict()
        
        # Check if we've already hit the API for this song
        if title in memo[artist]:
            temp = copy.copy(memo[artist][title])
        else:
            # Note: spotipy takes care of the 429 'retry-after' response from spotify
            temp = get_song(title, artist)
            
        if temp is not None:
            temp['date'] = song['date']
            temp['position'] = song['position']
            result_data += [temp]
        else:
            total_unfound += 1
        
        memo[artist][title] = temp

    # Batch the audio features into groups of 50, which is the max number you can query spotify at once
    song_list = divide_chunks(result_data, CHUNK_SIZE)
    result_features = []
    for sublist in song_list:
        sublist = list(map(lambda d: d['id'], sublist))
        # Add the audio features, remove unneeded one
        """
        Here are the features:
        dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode',
                   'speechiness', 'acousticness', 'instrumentalness', 'liveness',
                   'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
                   'analysis_url', 'duration_ms', 'time_signature'])"""
        features = sp.audio_features(sublist)
        features = list(map(del_unneeded, features))
        result_features += features
    
    # merge the features into the other song data
    result = list(zip(result_data, result_features))
    result = list(map(lambda a: combine_fn(a[0], a[1]), result))
    
    return pd.DataFrame(result).reset_index()

# %% [markdown]
# Here is an example of the functionality:

# %%
songs = [
    {'name': 'the business of emotion', 'artist': "big data featuring white sea", 'date': '2000-12-23'}
]
"""
    {'name': 'Independent Women Part I', 'artist': "Destiny's Child", 'date': '2000-12-23'}, not in
    {'name': 'He Loves U Not', 'artist': 'Dream', 'date': '2000-12-30'}, not in
    {'name': 'She Misses Him', 'artist': 'Tim Rushlow', 'date': '2000-12-30'}, not in
    {'name': 'Get Crunked Up', 'artist': 'Iconz Featuring Tony Manshino', 'date': '2000-12-30'} 69
    
    {'name': 'NAStradamus', 'artist': 'Nas', 'date': '2000-12-30'}
    {'name': 'Independent Women Part I', 'artist': "Destiny's Child", 'date': '2000-12-30'},
    {'name': 'Case Of The Ex (Whatcha Gonna Do)', 'artist': 'Mya', 'date': '2000-12-23'},
    {'name': "It Wasn't Me", 'artist': 'Shaggy Featuring Ricardo "RikRok" Ducent', 'date': '2000-12-30'},
    {'name': "It Wasn't Me", 'artist': 'Shaggy Featuring Ricardo "RikRok" Ducent', 'date': '2000-12-23'},
    {'name': 'Case Of The Ex (Whatcha Gonna Do)', 'artist': 'Mya', 'date': '2000-12-23'},
    {'name': 'I Wish', 'artist': 'R. Kelly', 'date': '??daf'}
"""
#Could not find 'fiesta' by 'r. kelly featuring jay-z' in top 20 results

#x = convert_all_songs(songs)
#x = get_song('NAStradamus', 'Nas')
x = get_song(songs[0]['name'], songs[0]['artist'])
print(x)
# Out:
# {'name': 'the business of emotion (feat. white sea)', 'id': '2TKso10B9HcIWy7HR1oP2g', 'artist': 'big data featuring white sea', 'popularity': 39}

# %% [markdown]
# Cool! Now that we have this functionality, lets run it on our data of top songs to create the end dataframe.

# %%
import pickle

with open('data/results/hot100Results', 'rb') as f:
    top_songs = pickle.load(f)

for elem in top_songs:
    for i in range(len(elem)):
        elem[i]['position'] = i + 1
top_songs = [song for year in top_songs for song in year] 
print(top_songs[99])

print(len(top_songs))
# Out:
# {'name': 'If I Am', 'artist': 'Nine Days', 'date': '2000-12-30', 'position': 100}
# 260685

# %%
top_songs[1600]
# Out:
# {'name': "Doesn't Really Matter",
#  'artist': 'Janet',
#  'date': '2000-09-09',
#  'position': 1}

# %%
import time
start = time.time()
result = convert_all_songs(top_songs)
print(time.time() - start)
print("Unique unfound: %s, total unfound: %s" % (unique_unfound, total_unfound))
# Out:
# Could not find 'love sets you free' by 'kelly price & friends' in top 20 results
# Could not find 'this gift' by '98 degrees' in top 20 results
# Could not find 'roll out (my business)' by 'ludacris' in top 20 results
# Could not find 'take away' by 'missy "misdemeanor" elliott featuring ginuwine & tweet' in top 20 results
# Could not find 'ooohhhwee' by 'master p featuring weebie' in top 20 results
# Could not find 'from her mama (mama got a**)' by 'juvenile' in top 20 results
# Could not find 'never too far/hero medley' by 'mariah carey' in top 20 results
# Could not find 'am to pm' by 'christina milian' in top 20 results
# Could not find 'do u wanna roll (dolittle theme)' by 'r.l., snoop dogg & lil' kim' in top 20 results
# Could not find 'god bless america' by 'daniel rodriguez' in top 20 results
# Could not find 'so complicated' by 'carolyn dawn johnson' in top 20 results
# Could not find 'what's going on' by 'all star tribute' in top 20 results
# Could not find 'one minute man' by 'missy "misdemeanor" elliott' in top 20 results
# Could not find 'i'll fly with you (l'amour toujours)' by 'gigi d'agostino' in top 20 results
# Could not find 'get ur freak on' by 'missy "misdemeanor" elliott' in top 20 results
# Could not find 'miss california' by 'dante thomas featuring pras' in top 20 results
# Could not find 'my baby' by 'lil' romeo' in top 20 results
# Could not find 'let's get it' by 'three the... g. dep, p. diddy & black rob' in top 20 results
# Could not find 'oochie wally' by 'qb finest featuring nas & bravehearts' in top 20 results
# Could not find 'get over yourself' by 'eden's crush' in top 20 results
# Could not find 'she misses him' by 'tim rushlow' in top 20 results
# Could not find 'i care 4 u' by 'aaliyah' in top 20 results
# Could not find 'thug lovin'' by 'ja rule featuring bobby brown' in top 20 results
# Could not find 'you can't hide beautiful' by 'aaron lines' in top 20 results
# Could not find 'addictive' by 'truth hurts featuring rakim' in top 20 results
# Could not find 'rapture (tastes so sweet)' by 'iio' in top 20 results
# Could not find 'sugarhigh' by 'jade anderson' in top 20 results
# Could not find 'take you home with me a.k.a. body' by 'r. kelly & jay-z' in top 20 results
# Could not find 'in another world' by 'joe diffie' in top 20 results
# Could not find 'bad boy this bad boy that' by 'bad boy's da band' in top 20 results
# Could not find 'come over' by 'aaliyah' in top 20 results
# Could not find 'love at 1st sight' by 'mary j. blige featuring method man' in top 20 results
# Could not find 'in love wit chu' by 'da brat featuring cherish' in top 20 results
# Could not find 'god bless the u.s.a.' by 'american idol finalists' in top 20 results
# Could not find 'make me a song' by 'kiley dean' in top 20 results
# Could not find 'p***ycat' by 'missy "misdemeanor" elliott' in top 20 results
# Could not find 'roll wit m.v.p. (we be like! the la la song)' by 'stagga lee' in top 20 results
# Could not find 'soldier's heart' by 'r. kelly' in top 20 results
# Could not find 'choppa style' by 'choppa featuring master p' in top 20 results
# Could not find 'new york' by 'ja rule featuring fat joe & jadakiss' in top 20 results
# Could not find 'you're my everything' by 'anita baker' in top 20 results
# Could not find 'big chips' by 'r. kelly & jay-z' in top 20 results
# Could not find 'u saved me' by 'r. kelly' in top 20 results
# Could not find 'got it twisted' by 'mobb deep' in top 20 results
# Could not find 'good little girls' by 'blue county' in top 20 results
# Could not find 'wild west show' by 'big & rich' in top 20 results
# Could not find 'love me right (oh sheila)' by 'angel city featuring lara mcallen' in top 20 results
# Could not find 'the set up' by 'obie trice featuring nate dogg' in top 20 results
# Could not find 'kryptonite (i'm on it)' by 'purple ribbon all-stars' in top 20 results
# Could not find 'listen to your heart' by 'd.h.t.' in top 20 results
# Could not find 'if you were mine' by 'marcos hernandez' in top 20 results
# Could not find 'charlie last name: wilson' by 'charlie wilson' in top 20 results
# Could not find 'welcome to jamrock' by 'damian "jr. gong" marley' in top 20 results
# Could not find 'and then what' by 'young jeezy featuring mannie fresh' in top 20 results
# Could not find 'baby i'm back' by 'baby bash featuring akon' in top 20 results
# Could not find 'mjb da mvp' by 'mary j. blige featuring the game & 50 cent' in top 20 results
# Could not find 'when you tell me that you love me' by 'american idol finalists season 4' in top 20 results
# Could not find 'in the kitchen' by 'r. kelly' in top 20 results
# Could not find 'cry baby/piece of my heart' by 'melissa etheridge & joss stone' in top 20 results
# Could not find 'holla at me' by 'dj khaled featuring lil wayne, paul wall, fat joe, rick ross & pitbull' in top 20 results
# Could not find 'soundtrack to your life' by 'ashley parker angel' in top 20 results
# Could not find 'breaking free' by 'zac efron, andrew seeley & vanessa anne hudgens' in top 20 results
# Could not find 'in the deep' by 'bird york' in top 20 results
# Could not find 'get'cha head in the game' by 'andrew seeley' in top 20 results
# Could not find 'what i've been looking for (reprise)' by 'andrew seeley & vanessa anne hudgens' in top 20 results
# Could not find 'i'm like a lawyer...(me & you)' by 'fall out boy' in top 20 results
# Could not find 'you are the music in me' by 'zac efron & vanessa anne hudgens' in top 20 results
# Could not find 'bet on it' by 'zac efron' in top 20 results
# Could not find 'everyday' by 'zac efron & vanessa anne hudgens' in top 20 results
# Could not find 'i don't dance' by 'corbin bleu & lucas grabeel' in top 20 results
# Could not find 'fabulous' by 'ashley tisdale & lucas grabeel' in top 20 results
# Could not find 'you can't stop the beat' by 'cast of hairspray' in top 20 results
# Could not find 'doomsday clock' by 'the smashing pumpkins' in top 20 results
# Could not find 'you give love a bad name' by 'blake lewis' in top 20 results
# Could not find 'a broken wing' by 'jordin sparks' in top 20 results
# Could not find 'tarantula' by 'the smashing pumpkins' in top 20 results
# Could not find 'i who have nothing' by 'jordin sparks' in top 20 results
# Could not find 'buddy' by 'musiq soulchild' in top 20 results
# Could not find 'i'll stand by you' by 'carrie underwood' in top 20 results
# Could not find 'time of the season' by 'blake lewis' in top 20 results
# Could not find 'do it just like a rockstar' by 'freak nasty featuring crazy mike' in top 20 results
# Could not find 'up to the mountain' by 'kelly clarkson featuring jeff beck' in top 20 results
# Could not find 'signal fire' by 'snow patrol' in top 20 results
# Could not find 'the neighbor' by 'dixie chicks' in top 20 results
# Could not find 'crazy car' by 'the naked brothers band' in top 20 results
# Could not find 'she got her own' by 'ne-yo featuring jamie foxx & fabolous' in top 20 results
# Could not find 'all summer long' by 'the rock heroes' in top 20 results
# Could not find 'too drunk...' by 'buckcherry' in top 20 results
# Could not find 'all summer long' by 'hit masters' in top 20 results
# Could not find 'american boy' by 'studio all-stars' in top 20 results
# Could not find 'warrior' by 'nelly' in top 20 results
# Could not find 'something special' by 'colbie caillat' in top 20 results
# Could not find 'game's pain' by 'the game featuring keyshia cole' in top 20 results
# Could not find 'in this moment' by 'david archuleta' in top 20 results
# Could not find 'always be my baby' by 'david cook' in top 20 results
# Could not find 'the music of the night' by 'david cook' in top 20 results
# Could not find 'i'm alive' by 'david cook' in top 20 results
# Could not find 'dreams collide' by 'colbie caillat' in top 20 results
# Could not find 'i won't tell' by 'fat joe featuring j. holiday' in top 20 results
# Could not find 'praying for time' by 'carrie underwood' in top 20 results
# Could not find 'many rivers to cross' by 'annie lennox' in top 20 results
# Could not find 'ching-a-ling' by 'missy elliott' in top 20 results
# Could not find 'on fire' by 'lil wayne' in top 20 results
# Could not find 'last chance' by 'ginuwine' in top 20 results
# Could not find 'send it on' by 'disney's friends for change' in top 20 results
# Could not find 'remember me' by 't.i. featuring mary j. blige' in top 20 results
# Could not find 'ain't no sunshine' by 'kris allen' in top 20 results
# Could not find 'a change is gonna come' by 'adam lambert' in top 20 results
# Could not find 'apologize' by 'kris allen' in top 20 results
# Could not find '3am' by 'eminem' in top 20 results
# Could not find 'f*ck you' by 'lily allen' in top 20 results
# Could not find 'top of the world' by 'the pussycat dolls' in top 20 results
# Could not find 'j**z in my pants' by 'the lonely island' in top 20 results
# Could not find 'boots' by 'the killers' in top 20 results
# Could not find 'one love (people get ready)' by 'glee cast' in top 20 results
# Could not find 'the big bang' by 'rockmafia' in top 20 results
# Could not find 'gonna get this' by 'hannah montana featuring iyaz' in top 20 results
# Could not find 'little white church' by 'little big town' in top 20 results
# Could not find 'la la la' by 'auburn featuring iyaz' in top 20 results
# Could not find 'eenie meenie' by 'sean kingston & justin bieber' in top 20 results
# Could not find 'to sir with love' by 'glee cast' in top 20 results
# Could not find 'i gotta get to you' by 'george strait' in top 20 results
# Could not find 'hallelujah' by 'lee dewyze' in top 20 results
# Could not find 'falling slowly' by 'lee dewyze & crystal bowersox' in top 20 results
# Could not find 'the boxer' by 'lee dewyze' in top 20 results
# Could not find 'who dat' by 'j. cole' in top 20 results
# Could not find 'make a wave' by 'disney's friends for change' in top 20 results
# Could not find 'driving me crazy' by 'sam adams' in top 20 results
# Could not find 'bridge over troubled water' by 'mary j. blige & andrea bocelli' in top 20 results
# Could not find 'f**k today' by 'lil wayne featuring gudda' in top 20 results
# Could not find 'lean on me' by 'sheryl crow, kid rock & keith urban' in top 20 results
# Could not find 'breathless' by 'taylor swift' in top 20 results
# Could not find 'stranded (haiti mon amour)' by 'jay-z, bono, the edge & rihanna' in top 20 results
# Could not find 'redemption song' by 'rihanna' in top 20 results
# Could not find 'love this pain' by 'lady antebellum' in top 20 results
# Could not find 'roman in moscow' by 'nicki minaj' in top 20 results
# Could not find 'hate sleeping alone' by 'drake' in top 20 results
# Could not find 'you and  i / you and i' by 'glee cast' in top 20 results
# Could not find 'it's good' by 'lil wayne featuring drake & jadakiss' in top 20 results
# Could not find 'we don't get down like y'all' by 't.i. featuring b.o.b.' in top 20 results
# Could not find 'boyfriend' by 'new hollow' in top 20 results
# Could not find 'big night' by 'big time rush' in top 20 results
# Could not find 'hit it again' by '3oh!3' in top 20 results
# Could not find 'i am the champion' by 'b.o.b' in top 20 results
# Could not find 'lover's eyes' by 'mumford & sons' in top 20 results
# Could not find 'my homies still' by 'lil wayne featuring big sean' in top 20 results
# Could not find 'one thing' by 'one direction' in top 20 results
# Could not find 'we've got tonight' by 'phillip phillips' in top 20 results
# Could not find 'way too cold' by 'kanye west featuring dj khaled' in top 20 results
# Could not find 'love this life' by 't.i.' in top 20 results
# Could not find 'at last' by 'will champlin' in top 20 results
# Could not find 'chinese food' by 'alison gold' in top 20 results
# Could not find 'don't drop that thun thun!' by 'the finatticz' in top 20 results
# Could not find 'i do it' by '2 chainz featuring drake & lil wayne' in top 20 results
# Could not find 'oh sweet lorraine' by 'green shoe studio featuring jacob colgan & fred stobaugh' in top 20 results
# Could not find 'gentleman' by 'psy' in top 20 results
# Could not find 'memories back then' by 'hustle gang featuring t.i., b.o.b, kendrick lamar & kris stephens' in top 20 results
# Could not find 'one way or another (teenage kicks)' by 'one direction' in top 20 results
# Could not find 'prayer in c' by 'lillywood & robin schulz' in top 20 results
# Could not find 'g.d.f.r.' by 'flo rida featuring sage the gemini & lookas' in top 20 results
# Could not find 'when i was your man' by 'chris jamison' in top 20 results
# Could not find 'cut her off' by 'kcamp featuring 2 chainz' in top 20 results
# Could not find 'b**** better have my money' by 'rihanna' in top 20 results
# Could not find 'my baby's got a smile on her face' by 'craig wayne boyd' in top 20 results
# Could not find 'broccoli' by 'd.r.a.m. featuring lil yachty' in top 20 results
# Could not find 'love make the world go round' by 'jennifer lopez & lin-manuel miranda' in top 20 results
# Could not find 'what the world needs now is love' by 'broadway for orlando' in top 20 results
# Could not find 'f**k love' by 'xxxtentacion featuring trippie redd' in top 20 results
# Could not find 'ask me how i know' by 'garth brooks' in top 20 results
# Could not find 'too hotty' by 'quavo, takeoff & offset' in top 20 results
# Could not find 'two' by 'lil uzi vert' in top 20 results
# Could not find 'it's goin' down' by 'descendants 2 cast' in top 20 results
# Could not find 'jerika' by 'jake paul & erika costell featuring uncle kade' in top 20 results
# Could not find 'the heart part 4' by 'kendrick lamar' in top 20 results
# Could not find 'w o r k i n  m e' by 'quavo' in top 20 results
# Could not find 'bigger > you' by '2 chainz, drake & quavo' in top 20 results
# Could not find 'cop shot the kid' by 'nas featuring kanye west' in top 20 results
# Could not find 'ye vs the people' by 'kanye west featuring t.i.' in top 20 results
# 1943.3105521202087
# Unique unfound: 178, total unfound: 15641

# %%
with open('hot100.df', 'wb') as f:
    pickle.dump(result, f)
